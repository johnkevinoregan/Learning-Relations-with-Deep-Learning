# %% [markdown]
# <a href="https://colab.research.google.com/github/johnkevinoregan/Learning-Relations-with-Deep-Learning/blob/main/Brightness_with_Background_judgement_on_1D_retina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brightness judgement on 1D retina
# ##First define functions used to create training examples with holes which are not trained

# %%
#K Generate training samples for Brightness judgement
#PixToSkip is the number of retinal pixels inbetween two successive retinal locations where there can be a training sample. You can use the value 0 if you dont want to skip locations.
#LeftNumToTrain is the number of retinal locations on the left side of the retina you want to train
#NumInHole is the number of those retinal locations in the center of the retina where you choose not to train (in order to test generalization)
#RightNumToTrain is the number of retinal locations on the right side of the retina you want to train
#As an example : generate_training_set(0,4,0,4) generates a training set with a retina of size 8 where all locations will be trained (+'s) and there is no hole: ++++++++ 
#generate_training_set(0,4,3,4) does the same except now there is a hole where there is no training (.'s): ++++...++++ (the retina is now of length 11)
#generate_training_set(1,4,3,4) does the same again, except now there are also skipped pixels inbetween all the training locations: +.+.+.+......+.+.+.+

#For this brightness task, each retinal locations gets 1 example with high brightness, and 1 with low brightness. 
#At each retinal location, the array X_locs_trained[] is updated by 0.5 for each brightness, so should equal 1 if the arrays are properly filled.

def generate_bright_training_set(Brightnesses,PixToSkip,LeftNumToTrain,NumInHole,RightNumToTrain): 
  TotNumToTrain=LeftNumToTrain+RightNumToTrain
  LastRetinaPixel=(TotNumToTrain+NumInHole-1)*(PixToSkip+1)
  Midpoint=LastRetinaPixel/2
  #print(Midpoint)
  X_trials=[[125 for col in range(LastRetinaPixel+1)] for row in range(2*TotNumToTrain)]
  X_locs_trained=[0 for col in range(LastRetinaPixel+1)]
  StepInterval=PixToSkip+1
  i=0
  for b in range(0,2):
    #print('b', b)
    for j in range(LeftNumToTrain):
      RetPos=j*StepInterval
      #print(i,RetPos)
      X_trials[i][RetPos]=Brightnesses[b]
      X_locs_trained[RetPos]+=0.5
      #print(X_trials[i])
      i+=1
      #print('left')
    for j in range(RightNumToTrain):
      RetPos=(LeftNumToTrain+NumInHole+j)*StepInterval
      #print(i,RetPos)
      X_trials[i][RetPos]=Brightnesses[b]
      X_locs_trained[RetPos]+=0.5
      #print(X_trials[i])
      i+=1
      #print('right')

  return(X_trials,X_locs_trained)

#K This function generates a list of all the possible tests for brightness judgements
#you must give it exactly the same parameters as for the training set so it can calculate how long the retina is
#even though for the test it actually has no holes or skipped pixels at all.
def generate_bright_test_set(Brightnesses,PixToSkip,LeftNumToTrain,NumInHole,RightNumToTrain):
  TotNumToTrain=LeftNumToTrain+RightNumToTrain
  RetinaSize=(TotNumToTrain+NumInHole-1)*(PixToSkip+1)+1
  AllPossTests=[[125 for row in range(RetinaSize)] for col in range(2*RetinaSize)]
  for b in range(0,2):
    #print('b',b)
    for i in range(RetinaSize):
      AllPossTests[i+b*RetinaSize][i]=Brightnesses[b]
  return(AllPossTests)

# K generate labels based on the index of 1 in each row of the Training or Test set
def generate_bright_labels(Brightnesses,Set):
  Labels=[0 if max(row)==Brightnesses[0] else 1 for row in Set]
  return Labels

# %% [markdown]
# ##Second, make training sets X_train and labels y_train, and testing sets X_test and labels y_test

# %%
Brightnesses=[155,195]
X_train,X_locs_trained=generate_bright_training_set(Brightnesses,3,6,10,6)

#If we dont shuffle the training set, there may be a left-right sequence bias on the training.
#np.random.shuffle(X_train)
y_train=generate_bright_labels(Brightnesses,X_train)
print('locations trained')
print(X_locs_trained)
print()

print('training set')
for i in range(len(X_train)):
  print(X_train[i], 'label',y_train[i])
print()

X_test=generate_bright_test_set(Brightnesses,3,6,10,6)
y_test=generate_bright_labels(Brightnesses,X_test)
#print('test set')
for i in range(len(X_test)):
  print(X_test[i], 'label',y_test[i])
print()

# %% [markdown]
# ## Then either: train with normal NN

# %%
# Build, compile and train the neural network model
#there are two hidden layers with 64 and 32 values
#The ReLU activation function is used in deep learning models to introduce non-linearity into the network
#the sigmoid activation function produces a probability value between 0 and 1
from tensorflow import keras
import numpy as np
#from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
#from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping


model = keras.models.Sequential([
    keras.layers.Dense(64, activation="relu", input_dim=len(X_train[0])),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

#We're not using the splitting function since we're training our own particular set of examples
# Split the data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(df, labels, test_size=0.2, random_state=42)

# Train the model
#I wanted to make it stop when there was no more improvement, but it stops immediately no matter what I do
#early_stopping = EarlyStopping()
#custom_early_stopping = EarlyStopping(
#    monitor='val_accuracy', 
#    patience=20, 
#    min_delta=0.001, 
#    mode='max'
#)
#model.fit(X_train, y_train, epochs=160, batch_size=32, validation_data=(X_test, y_test),callbacks=[early_stopping])

model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 57.6209 - accuracy: 0.5000 - val_loss: 34.2349 - val_accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 84ms/step - loss: 35.8210 - accuracy: 0.5000 - val_loss: 13.4136 - val_accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 86ms/step - loss: 15.0629 - accuracy: 0.5000 - val_loss: 7.7820 - val_accuracy: 0.4941
# Epoch 4/200
# 1/1 [==============================] - 0s 76ms/step - loss: 7.0579 - accuracy: 0.5000 - val_loss: 16.1399 - val_accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 89ms/step - loss: 15.4468 - accuracy: 0.5000 - val_loss: 17.0656 - val_accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 70ms/step - loss: 16.3795 - accuracy: 0.5000 - val_loss: 13.2614 - val_accuracy: 0.5000
# Epoch 7/200
# 1/1 [==============================] - 0s 88ms/step - loss: 12.5773 - accuracy: 0.5000 - val_loss: 6.2021 - val_accuracy: 0.4882
# Epoch 8/200
# 1/1 [==============================] - 0s 74ms/step - loss: 5.4822 - accuracy: 0.5000 - val_loss: 3.2835 - val_accuracy: 0.5706
# Epoch 9/200
# 1/1 [==============================] - 0s 75ms/step - loss: 4.5612 - accuracy: 0.5000 - val_loss: 7.3310 - val_accuracy: 0.5059
# Epoch 10/200
# 1/1 [==============================] - 0s 105ms/step - loss: 8.7969 - accuracy: 0.5000 - val_loss: 7.8687 - val_accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 118ms/step - loss: 9.3233 - accuracy: 0.5000 - val_loss: 5.5095 - val_accuracy: 0.5176
# Epoch 12/200
# 1/1 [==============================] - 0s 96ms/step - loss: 6.9220 - accuracy: 0.5000 - val_loss: 1.8944 - val_accuracy: 0.5647
# Epoch 13/200
# 1/1 [==============================] - 0s 97ms/step - loss: 2.5390 - accuracy: 0.5000 - val_loss: 5.3076 - val_accuracy: 0.4882
# Epoch 14/200
# Epoch 191/200
# 1/1 [==============================] - 0s 121ms/step - loss: 1.2075 - accuracy: 0.3750 - val_loss: 1.6862 - val_accuracy: 0.4529
# Epoch 192/200
# 1/1 [==============================] - 0s 120ms/step - loss: 1.2027 - accuracy: 0.3750 - val_loss: 1.6844 - val_accuracy: 0.4529
# Epoch 193/200
# 1/1 [==============================] - 0s 125ms/step - loss: 1.1980 - accuracy: 0.3750 - val_loss: 1.6829 - val_accuracy: 0.4529
# Epoch 194/200
# 1/1 [==============================] - 0s 97ms/step - loss: 1.1933 - accuracy: 0.3750 - val_loss: 1.6815 - val_accuracy: 0.4529
# Epoch 195/200
# 1/1 [==============================] - 0s 110ms/step - loss: 1.1886 - accuracy: 0.3750 - val_loss: 1.6798 - val_accuracy: 0.4529
# Epoch 196/200
# 1/1 [==============================] - 0s 107ms/step - loss: 1.1839 - accuracy: 0.3750 - val_loss: 1.6785 - val_accuracy: 0.4529
# Epoch 197/200
# 1/1 [==============================] - 0s 103ms/step - loss: 1.1792 - accuracy: 0.3750 - val_loss: 1.6767 - val_accuracy: 0.4529
# Epoch 198/200
# 1/1 [==============================] - 0s 126ms/step - loss: 1.1746 - accuracy: 0.3750 - val_loss: 1.6754 - val_accuracy: 0.4529
# Epoch 199/200
# 1/1 [==============================] - 0s 114ms/step - loss: 1.1699 - accuracy: 0.3750 - val_loss: 1.6738 - val_accuracy: 0.4529
# Epoch 200/200
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1652 - accuracy: 0.3750 - val_loss: 1.6723 - val_accuracy: 0.4529

# %% [markdown]
# ###Test normal NN on all retinal positions

# %%
#Test on all retinal positions including non-trained ones
# NB the logic is different compared to the Left/Right judgement task!!
# We plot separately the predictions for the two brightness levels at each RetPos
NumTrials=len(X_test)
RetinaSize=len(X_test[0])
resultsNN=[[0 for row in range(0,2)] for col in range(RetinaSize)]
for trial in range(NumTrials):
  pred=model.predict(np.array([X_test[trial]]))
  estimate=pred[0][0]
  bright=max(X_test[trial])
  which=Brightnesses.index(bright)
  RetPos=X_test[trial].index(bright)
  print(which,RetPos,estimate)
  resultsNN[RetPos][which]=estimate
print(resultsNN)
# Out:
# 1/1 [==============================] - 0s 130ms/step
# 0 0 0.6620005
# 1/1 [==============================] - 0s 35ms/step
# 0 1 0.8596055
# 1/1 [==============================] - 0s 33ms/step
# 0 2 0.5606228
# 1/1 [==============================] - 0s 41ms/step
# 0 3 0.7601689
# 1/1 [==============================] - 0s 34ms/step
# 0 4 0.85734123
# 1/1 [==============================] - 0s 44ms/step
# 0 5 0.9215204
# 1/1 [==============================] - 0s 37ms/step
# 0 6 0.51128614
# 1/1 [==============================] - 0s 38ms/step
# 0 7 0.98922944
# 1/1 [==============================] - 0s 36ms/step
# 0 8 0.5220579
# 1/1 [==============================] - 0s 43ms/step
# 0 9 0.9987053
# 1/1 [==============================] - 0s 37ms/step
# 0 10 0.041169364
# 1/1 [==============================] - 0s 43ms/step
# 0 11 0.9866081
# 1/1 [==============================] - 0s 47ms/step
# 0 12 0.913243
# 1/1 [==============================] - 0s 53ms/step
# 0 13 0.96572053
# 1/1 [==============================] - 0s 39ms/step
# 0 14 0.5933262
# 1/1 [==============================] - 0s 26ms/step
# 0 15 0.5301466
# 1/1 [==============================] - 0s 27ms/step
# 0 16 0.73632795
# 1/1 [==============================] - 0s 26ms/step
# 0 17 0.063544974
# 1/1 [==============================] - 0s 24ms/step
# 0 18 0.9260936
# 1/1 [==============================] - 0s 26ms/step
# 0 19 0.22506508
# 1/1 [==============================] - 0s 23ms/step
# 0 20 0.57387
# 1/1 [==============================] - 0s 28ms/step
# 0 21 0.62209207
# 1/1 [==============================] - 0s 25ms/step
# 0 22 0.93784535
# 1/1 [==============================] - 0s 23ms/step
# 0 23 0.3451733
# 1/1 [==============================] - 0s 30ms/step
# 0 24 0.10975941
# 1/1 [==============================] - 0s 25ms/step
# 0 25 0.0028373434
# 1/1 [==============================] - 0s 26ms/step
# 0 26 0.92431533
# 1/1 [==============================] - 0s 25ms/step
# 0 27 0.9660309
# 1/1 [==============================] - 0s 27ms/step
# 0 28 0.0021882183
# 1/1 [==============================] - 0s 25ms/step
# 0 29 0.30058387
# 1/1 [==============================] - 0s 25ms/step
# 0 30 0.98173505
# 1/1 [==============================] - 0s 28ms/step
# 0 31 0.1796356
# 1/1 [==============================] - 0s 24ms/step
# 0 32 0.20265818
# 1/1 [==============================] - 0s 24ms/step
# 0 33 0.8068936
# 1/1 [==============================] - 0s 25ms/step
# 0 34 0.83525556
# 1/1 [==============================] - 0s 27ms/step
# 0 35 0.10279374
# 1/1 [==============================] - 0s 24ms/step
# 0 36 0.18969454
# 1/1 [==============================] - 0s 26ms/step
# 0 37 0.84038997
# 1/1 [==============================] - 0s 25ms/step
# 0 38 0.92645955
# 1/1 [==============================] - 0s 27ms/step
# 0 39 0.8908023
# 1/1 [==============================] - 0s 24ms/step
# 0 40 0.23642078
# 1/1 [==============================] - 0s 24ms/step
# 0 41 0.88316804
# 1/1 [==============================] - 0s 28ms/step
# 0 42 0.88571936
# 1/1 [==============================] - 0s 28ms/step
# 0 43 0.90435296
# 1/1 [==============================] - 0s 25ms/step
# 0 44 0.7711962
# 1/1 [==============================] - 0s 29ms/step
# 0 45 0.6677805
# 1/1 [==============================] - 0s 28ms/step
# 0 46 0.99276775
# 1/1 [==============================] - 0s 27ms/step
# 0 47 0.7996541
# 1/1 [==============================] - 0s 24ms/step
# 0 48 0.90332514
# 1/1 [==============================] - 0s 24ms/step
# 0 49 0.7297628
# 1/1 [==============================] - 0s 24ms/step
# 0 50 0.8509383
# 1/1 [==============================] - 0s 24ms/step
# 0 51 0.6588107
# 1/1 [==============================] - 0s 26ms/step
# 0 52 0.57783735
# 1/1 [==============================] - 0s 25ms/step
# 0 53 0.70248455
# 1/1 [==============================] - 0s 25ms/step
# 0 54 0.21295644
# 1/1 [==============================] - 0s 24ms/step
# 0 55 0.6449954
# 1/1 [==============================] - 0s 25ms/step
# 0 56 0.99616677
# 1/1 [==============================] - 0s 26ms/step
# 0 57 0.96853906
# 1/1 [==============================] - 0s 26ms/step
# 0 58 0.14744075
0.99880517], [0.83944803, 0.9410807], [0.99309224, 0.99997276], [0.4528137, 0.16749132], [0.84986216, 0.94699866], [0.39115465, 0.10026921], [0.20116138, 0.012374614], [0.32300663, 0.052728776], [0.30971807, 0.04600827], [0.45876062, 0.17542902], [0.9683958, 0.99891347], [0.31879026, 0.05052031], [0.26699802, 0.02879618], [0.5405501, 0.3137781], [0.79242873, 0.8769621], [0.35676208, 0.073290914], [0.24800727, 0.022974623], [0.22087891, 0.016252337], [0.8753781, 0.9672866], [0.83068424, 0.9275268], [0.6760399, 0.635214], [0.31434226, 0.04826609], [0.98678976, 0.99986404], [0.9675424, 0.9988415], [0.7009479, 0.7084517], [0.63549054, 0.533733]]

# %% [markdown]
# ###Plot Result for normal NN

# %%
#import numpy as np
#arr = np.array(resultsNN)
#print(np.round(arr, decimals=2))

import matplotlib.pyplot as plt
plt.suptitle('prediction for each location')
plt.plot(resultsNN)
plt.show()
print()
plt.suptitle('locations trained')
plt.plot(X_locs_trained)

# %%
import matplotlib.pyplot as plt
plt.suptitle('prediction for each location with training locations superimposed in green')
plt.plot(resultsNN)

plt.plot(X_locs_trained)

# %% [markdown]
# Comment on results:
#
# The normal NN has a global bias to give a higher prediction value for the bright pixels than the dark pixels. The last graph shows that for the bright pixelzs accuracy is good at the training locations, but can be random at the other locations. For the dark pixels, the NN has a bias to give a low prediction value everywhere, so training locations has little impact on the predictions.

# %% [markdown]
# ## Or: Train with CNN

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=(len(X_train[0]), 1)))
model.add(MaxPooling1D(pool_size=5))
#model.add(Conv1D(filters=64, kernel_size=5, activation='relu'))
#model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

#loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
#print("Accuracy:", accuracy)

# %% [markdown]
# ###Test CNN on all retinal positions

# %%
#Test on all retinal positions including non-trained ones
# NB the logic is different compared to the Left/Right judgement task!!
# We plot separately the predictions for the two brightness levels at each RetPos
NumTrials=len(X_test)
RetinaSize=len(X_test[0])
resultsCNN=[[0 for row in range(0,2)] for col in range(RetinaSize)]
for trial in range(NumTrials):
  pred=model.predict(np.array([X_test[trial]]))
  estimate=pred[0][0]
  bright=max(X_test[trial])
  which=Brightnesses.index(bright)
  RetPos=X_test[trial].index(bright)
  print(which,RetPos,estimate)
  resultsCNN[RetPos][which]=estimate
print(resultsCNN)

# %% [markdown]
# ###Plot result for CNN

# %%
#import numpy as np
#arr = np.array(results)
#print(np.round(arr, decimals=2))

import matplotlib.pyplot as plt
plt.suptitle('prediction for each location')
plt.plot(resultsCNN)
plt.show()
print()
plt.suptitle('locations trained')
plt.plot(X_locs_trained)

# %%
import matplotlib.pyplot as plt
plt.suptitle('prediction for each location with training locations superimposed in green')
plt.plot(resultsCNN)

plt.plot(X_locs_trained)

# %% [markdown]
# Comment on results:
#
# Using a CNN smooths the results as compared to a normal NN. By increasing the values of kernel size or of max pooling size you can increase the degree of smoothing. For the bright pixels, in the locations where training is skipped, predictions nevertheless get a little worse, and really bad in the hole in the middle of the retina. The CNN has a bias to predict a pixel is dark if it has not been trained (as in the hole). There's a slight effect of doing the training order in a left to right sequence along the retina -- this can be seen by not doing the random shuffling of the training set in the training data creation.
