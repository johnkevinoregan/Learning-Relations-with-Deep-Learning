# %% [markdown]
# <a href="https://colab.research.google.com/github/johnkevinoregan/Learning-Relations-with-Deep-Learning/blob/main/Brightness_generalisation_on_1d_retina_with_skips_DONT_CHANGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bright/Dark judgement on 1D retina: generalization to untrained retinal locations and untrained brightnesses
# *PLEASE DON'T CHANGE THIS NOTEBOOK -- MAKE A COPY if you want to play with parameters!*
#
# ---
#
# ##Functions used to create training examples

# %%
#K Generate training samples for Brightness judgement
#PixToSkip is the number of retinal pixels inbetween two successive retinal locations where there can be a training sample. You can use the value 0 if you dont want to skip locations.
#LeftNumToTrain is the number of retinal locations on the left side of the retina you want to train
#NumInHole is the number of those retinal locations in the center of the retina where you choose not to train (in order to test generalization)
#RightNumToTrain is the number of retinal locations on the right side of the retina you want to train
#As an example : generate_training_set(0,4,0,4) generates a training set with a retina of size 8 where all locations will be trained (+'s) and there is no hole: ++++++++ 
#generate_training_set(0,4,3,4) does the same except now there is a hole where there is no training (.'s): ++++...++++ (the retina is now of length 11)
#generate_training_set(1,4,3,4) does the same again, except now there are also skipped pixels inbetween all the training locations: +.+.+.+......+.+.+.+

#For this brightness task, each retinal locations gets 1 example with high brightness, and 1 with low brightness. 
#At each retinal location, the array X_locs_trained[] is updated by 0.5 for each brightness, so should equal 1 if the arrays are properly filled.

#NB at first I had a background of 0's. I found that in that case there was a bias to give a good prediction to dim pixels. In untrained locations there was therefore a tendency to incorrectly report bright pixels as dim.
#But putting a background of 125 and making dim and bright symmetrically placed with respect to that middle value, things became more reasonable.

def generate_bright_training_set(BackGround,Brightnesses,PixToSkip,LeftNumToTrain,NumInHole,RightNumToTrain): 
  TotNumToTrain=LeftNumToTrain+RightNumToTrain
  LastRetinaPixel=(TotNumToTrain+NumInHole-1)*(PixToSkip+1)
  Midpoint=LastRetinaPixel/2
  #print(Midpoint)
  X_trials=[[BackGround for col in range(LastRetinaPixel+1)] for row in range(2*TotNumToTrain)]
  X_locs_trained=[0 for col in range(LastRetinaPixel+1)]
  StepInterval=PixToSkip+1
  i=0
  for b in range(0,2):
    #print('b', b)
    for j in range(LeftNumToTrain):
      RetPos=j*StepInterval
      #print(i,RetPos)
      X_trials[i][RetPos]=Brightnesses[b]
      X_locs_trained[RetPos]+=0.5
      #print(X_trials[i])
      i+=1
      #print('left')
    for j in range(RightNumToTrain):
      RetPos=(LeftNumToTrain+NumInHole+j)*StepInterval
      #print(i,RetPos)
      X_trials[i][RetPos]=Brightnesses[b]
      X_locs_trained[RetPos]+=0.5
      #print(X_trials[i])
      i+=1
      #print('right')

  return(X_trials,X_locs_trained)

#K This function generates a list of all the possible tests for brightness judgements
#you must give it exactly the same parameters as for the training set so it can calculate how long the retina is
#even though for the test it actually has no holes or skipped pixels at all.
def generate_bright_test_set(BackGround,Brightnesses,PixToSkip,LeftNumToTrain,NumInHole,RightNumToTrain):
  TotNumToTrain=LeftNumToTrain+RightNumToTrain
  RetinaSize=(TotNumToTrain+NumInHole-1)*(PixToSkip+1)+1
  AllPossTests=[[BackGround for row in range(RetinaSize)] for col in range(2*RetinaSize)]
  for b in range(0,2):
    #print('b',b)
    for i in range(RetinaSize):
      AllPossTests[i+b*RetinaSize][i]=Brightnesses[b]
  return(AllPossTests)

# K generate labels based on the index of 1 in each row of the Training or Test set
def generate_bright_labels(Brightnesses,Set):
  Labels=[0 if Brightnesses[0] in row else 1 for row in Set]
  
 # Labels=[0 for col in range(len(Set))]
 # for i in range(len(Set)):
 #   if max(Set[i])==Brightnesses[0]:
 #     Labels[i]=0
 #   else:
 #     Labels[i]=1
  #Labels=[0 if max(row)==Brightnesses[0] else 1 for row in Set]
  return Labels

# %% [markdown]
# ##Make training sets X_train and labels y_train

# %%
BackGround=125
Brightnesses=[125-62,125+62]
skip=3
left=5
hole=10
right=5

X_train,X_locs_trained=generate_bright_training_set(BackGround,Brightnesses,skip,left,hole,right)

#If we dont shuffle the training set, there may be a left-right sequence bias on the training.
import numpy as np
np.random.shuffle(X_train)
y_train=generate_bright_labels(Brightnesses,X_train)
print('locations trained')
print(X_locs_trained)
print()

print('training set')
for i in range(len(X_train)):
  print(X_train[i], 'label',y_train[i])
print()

# %% [markdown]
# ## Train with normal NN

# %%
# Build, compile and train the neural network model
#there are two hidden layers with 64 and 32 values
#The ReLU activation function is used in deep learning models to introduce non-linearity into the network
#the sigmoid activation function produces a probability value between 0 and 1
from tensorflow import keras
import numpy as np
#from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
#from sklearn.model_selection import train_test_split
#from tensorflow.keras.callbacks import EarlyStopping


model = keras.models.Sequential([
    keras.layers.Dense(64, activation="relu", input_dim=len(X_train[0])),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

#model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))
model.fit(X_train, y_train, epochs=200, batch_size=32)

# %% [markdown]
# ###Test normal NN
# Check for generalization to:
# - untrained retinal positions
# - and  at 2 delta values on either side of original brightness levels

# %%
import matplotlib.pyplot as plt
print('locations trained')
plt.plot(X_locs_trained)
plt.show()

for BrightDelta in range(-45,46,15):
  temp=np.add(Brightnesses,[BrightDelta,-BrightDelta])
  BrightnessesChanged=temp.tolist()

  X_test=generate_bright_test_set(BackGround,BrightnessesChanged,skip,left,hole,right)
  y_test=generate_bright_labels(BrightnessesChanged,X_test)
  #print('test set')
  #for i in range(len(X_test)):
  #  print(X_test[i], 'label',y_test[i])
  #print()


  #Test on all retinal positions including non-trained ones
  # We plot separately the predictions for the two brightness levels at each RetPos
  NumTrials=len(X_test)
  RetinaSize=len(X_test[0])
  resultsNN=[[0 for row in range(0,2)] for col in range(RetinaSize)]
  for trial in range(NumTrials):
    pred=model.predict(np.array([X_test[trial]]), verbose=0)
    estimate=pred[0][0]
    bright=BrightnessesChanged[y_test[trial]]
    which=BrightnessesChanged.index(bright)
    RetPos=X_test[trial].index(bright)
    #print(which,RetPos,estimate)
    resultsNN[RetPos][which]=estimate
  #print(resultsNN)
  print('trained Brightnesses:',Brightnesses, 'tested with',BrightnessesChanged,'Delta:', BrightDelta)

  import matplotlib.pyplot as plt
  #plt.suptitle('BrightDelta',BrightDelta)
  plt.plot(resultsNN)
  plt.show()
# Out:
# locations trained
# trained Brightnesses: [63, 187] tested with [18, 232] Delta: -45
# trained Brightnesses: [63, 187] tested with [33, 217] Delta: -30
# trained Brightnesses: [63, 187] tested with [48, 202] Delta: -15
# trained Brightnesses: [63, 187] tested with [63, 187] Delta: 0
# trained Brightnesses: [63, 187] tested with [78, 172] Delta: 15
# trained Brightnesses: [63, 187] tested with [93, 157] Delta: 30
# trained Brightnesses: [63, 187] tested with [108, 142] Delta: 45

# %% [markdown]
# Comment on results:
# - it's difficult to see from these graphs, but accuracy is 1 at the trained locations. Elsewhere in the skipped locations, responses seem to be largely *opposite* the trained locations for some reason. In the hole responses are random but dim and bright decisions are opposite.
# - concerning generalization to untrained brightnesses: just as for the case where there are no skipped pixels, when the test brightnesses are closer to the extremes of 0 and 255 the NN interestingly does better than for the trained values of [63,187]. When the test brightnesses are closer to the background value of 125, the NN does worse.

# %% [markdown]
# ## Train with CNN

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=4, activation='relu', input_shape=(len(X_train[0]), 1)))
model.add(MaxPooling1D(pool_size=4))
#model.add(Conv1D(filters=64, kernel_size=5, activation='relu'))
#model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=32, verbose=1)

#loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
#print("Accuracy:", accuracy)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 776ms/step - loss: 18.1634 - accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9326 - accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 31ms/step - loss: 10.8167 - accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 15ms/step - loss: 9.5489 - accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 19ms/step - loss: 3.7486 - accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 18ms/step - loss: 4.2730 - accuracy: 0.5000
# Epoch 7/200
# 1/1 [==============================] - 0s 13ms/step - loss: 7.0202 - accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 18ms/step - loss: 6.3220 - accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 47ms/step - loss: 3.2284 - accuracy: 0.5000
# Epoch 10/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4975 - accuracy: 0.5000
# Epoch 11/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.6687 - accuracy: 0.5000
# Epoch 12/200
# 1/1 [==============================] - 0s 24ms/step - loss: 3.5441 - accuracy: 0.5000
# Epoch 13/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.6743 - accuracy: 0.5000
# Epoch 14/200
# 1/1 [==============================] - 0s 40ms/step - loss: 1.5346 - accuracy: 0.6000
# Epoch 15/200
# 1/1 [==============================] - 0s 39ms/step - loss: 2.8480 - accuracy: 0.5000
# Epoch 16/200
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5648 - accuracy: 0.5000
# Epoch 17/200
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0535 - accuracy: 0.6000
# Epoch 18/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.6728 - accuracy: 0.5000
# Epoch 19/200
# 1/1 [==============================] - 0s 30ms/step - loss: 2.4051 - accuracy: 0.5000
# Epoch 20/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6889 - accuracy: 0.5000
# Epoch 21/200
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8595 - accuracy: 0.5500
# Epoch 22/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.7028 - accuracy: 0.5500
# Epoch 23/200
# 1/1 [==============================] - 0s 33ms/step - loss: 1.7589 - accuracy: 0.5500
# Epoch 24/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9620 - accuracy: 0.6000
# Epoch 25/200
# 1/1 [==============================] - 0s 23ms/step - loss: 1.1647 - accuracy: 0.5500
# Epoch 26/200
# 1/1 [==============================] - 0s 31ms/step - loss: 1.5895 - accuracy: 0.5000
# Epoch 27/200
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0394 - accuracy: 0.5500
# Epoch 28/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9288 - accuracy: 0.6000
# Epoch 29/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3562 - accuracy: 0.6000
# Epoch 30/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0784 - accuracy: 0.6000
# Epoch 31/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7887 - accuracy: 0.5000
# Epoch 32/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1654 - accuracy: 0.5500
# Epoch 33/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9955 - accuracy: 0.5500
# Epoch 34/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7616 - accuracy: 0.5000
# Epoch 35/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0340 - accuracy: 0.6000
# Epoch 36/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9079 - accuracy: 0.6500
# Epoch 37/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7317 - accuracy: 0.5000
# Epoch 38/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9476 - accuracy: 0.5500
# Epoch 39/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7969 - accuracy: 0.4500
# Epoch 40/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7365 - accuracy: 0.6000
# Epoch 41/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.8715 - accuracy: 0.6500
# Epoch 42/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7105 - accuracy: 0.6000
# Epoch 43/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7399 - accuracy: 0.4500
# Epoch 44/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7881 - accuracy: 0.5500
# Epoch 45/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6509 - accuracy: 0.6000
# Epoch 46/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7422 - accuracy: 0.6500
# Epoch 47/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6946 - accuracy: 0.6500
# Epoch 48/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6446 - accuracy: 0.5000
# Epoch 49/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7096 - accuracy: 0.5500
# Epoch 50/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6180 - accuracy: 0.6000
# Epoch 51/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6563 - accuracy: 0.6500
# Epoch 52/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6412 - accuracy: 0.6500
# Epoch 53/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5967 - accuracy: 0.6000
# Epoch 54/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6382 - accuracy: 0.5500
# Epoch 55/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5789 - accuracy: 0.6000
# Epoch 56/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6020 - accuracy: 0.7000
# Epoch 57/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5844 - accuracy: 0.7000
# Epoch 58/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5615 - accuracy: 0.6000
# Epoch 59/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5796 - accuracy: 0.6500
# Epoch 60/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5397 - accuracy: 0.7000
# Epoch 61/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5578 - accuracy: 0.7000
# Epoch 62/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5330 - accuracy: 0.8000
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5318 - accuracy: 0.7000
# Epoch 64/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5304 - accuracy: 0.7500
# Epoch 65/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5119 - accuracy: 0.7500
# Epoch 66/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5185 - accuracy: 0.8000
# Epoch 67/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4976 - accuracy: 0.7500
# Epoch 68/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5044 - accuracy: 0.7500
# Epoch 69/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4897 - accuracy: 0.7500
# Epoch 70/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4884 - accuracy: 0.8000
# Epoch 71/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4821 - accuracy: 0.8000
# Epoch 72/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4734 - accuracy: 0.8000
# Epoch 73/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4742 - accuracy: 0.8000
# Epoch 74/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4625 - accuracy: 0.8000
# Epoch 75/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4630 - accuracy: 0.8000
# Epoch 76/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4518 - accuracy: 0.8000
# Epoch 77/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4520 - accuracy: 0.8500
# Epoch 78/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4431 - accuracy: 0.8500
# Epoch 79/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4409 - accuracy: 0.8000
# Epoch 80/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4352 - accuracy: 0.8000
# Epoch 81/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4300 - accuracy: 0.8500
# Epoch 82/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4270 - accuracy: 0.8500
# Epoch 83/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4210 - accuracy: 0.8500
# Epoch 84/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4188 - accuracy: 0.8500
# Epoch 85/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4119 - accuracy: 0.8500
# Epoch 86/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4100 - accuracy: 0.8500
# Epoch 87/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4038 - accuracy: 0.8500
# Epoch 88/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4018 - accuracy: 0.8500
# Epoch 89/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3966 - accuracy: 0.8500
# Epoch 90/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3936 - accuracy: 0.8500
# Epoch 91/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3888 - accuracy: 0.8500
# Epoch 92/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3859 - accuracy: 0.8500
# Epoch 93/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3825 - accuracy: 0.8500
# Epoch 94/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3775 - accuracy: 0.8500
# Epoch 95/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3750 - accuracy: 0.8500
# Epoch 96/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3706 - accuracy: 0.8500
# Epoch 97/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3679 - accuracy: 0.8500
# Epoch 98/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3636 - accuracy: 0.8500
# Epoch 99/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3612 - accuracy: 0.8500
# Epoch 100/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3574 - accuracy: 0.8500
# Epoch 101/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3546 - accuracy: 0.8500
# Epoch 102/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3512 - accuracy: 0.8500
# Epoch 103/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3480 - accuracy: 0.8500
# Epoch 104/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3453 - accuracy: 0.8500
# Epoch 105/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3421 - accuracy: 0.8500
# Epoch 106/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3393 - accuracy: 0.8500
# Epoch 107/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3368 - accuracy: 0.8500
# Epoch 108/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3342 - accuracy: 0.8500
# Epoch 109/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3317 - accuracy: 0.8500
# Epoch 110/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3296 - accuracy: 0.8500
# Epoch 111/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3268 - accuracy: 0.8500
# Epoch 112/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3251 - accuracy: 0.8500
# Epoch 113/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3226 - accuracy: 0.8500
# Epoch 114/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3198 - accuracy: 0.8500
# Epoch 115/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3173 - accuracy: 0.8500
# Epoch 116/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3156 - accuracy: 0.8500
# Epoch 117/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3134 - accuracy: 0.8500
# Epoch 118/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3106 - accuracy: 0.8500
# Epoch 119/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3084 - accuracy: 0.8500
# Epoch 120/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3067 - accuracy: 0.8500
# Epoch 121/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3045 - accuracy: 0.8500
# Epoch 122/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3021 - accuracy: 0.8500
# Epoch 123/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3003 - accuracy: 0.8500
# Epoch 124/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2981 - accuracy: 0.8500
# Epoch 125/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2960 - accuracy: 0.8500
# Epoch 126/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2945 - accuracy: 0.8500
# Epoch 127/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2925 - accuracy: 0.8500
# Epoch 128/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2908 - accuracy: 0.8500
# Epoch 129/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2890 - accuracy: 0.8500
# Epoch 130/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2869 - accuracy: 0.8500
# Epoch 131/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2850 - accuracy: 0.8500
# Epoch 132/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2838 - accuracy: 0.8500
# Epoch 133/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2818 - accuracy: 0.8500
# Epoch 134/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2802 - accuracy: 0.8500
# Epoch 135/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2786 - accuracy: 0.8500
# Epoch 136/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2766 - accuracy: 0.8500
# Epoch 137/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2757 - accuracy: 0.8500
# Epoch 138/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2742 - accuracy: 0.8500
# Epoch 139/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2721 - accuracy: 0.8500
# Epoch 140/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2706 - accuracy: 0.8500
# Epoch 141/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2696 - accuracy: 0.8500
# Epoch 142/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2678 - accuracy: 0.8500
# Epoch 143/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2658 - accuracy: 0.8500
# Epoch 144/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2647 - accuracy: 0.8500
# Epoch 145/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2636 - accuracy: 0.8500
# Epoch 146/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2617 - accuracy: 0.8500
# Epoch 147/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2600 - accuracy: 0.8500
# Epoch 148/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2590 - accuracy: 0.8500
# Epoch 149/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2575 - accuracy: 0.8500
# Epoch 150/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2557 - accuracy: 0.8500
# Epoch 151/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2550 - accuracy: 0.8500
# Epoch 152/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2538 - accuracy: 0.8500
# Epoch 153/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2519 - accuracy: 0.8500
# Epoch 154/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2508 - accuracy: 0.8500
# Epoch 155/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2499 - accuracy: 0.8500
# Epoch 156/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2486 - accuracy: 0.8500
# Epoch 157/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2470 - accuracy: 0.8500
# Epoch 158/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2451 - accuracy: 0.9000
# Epoch 159/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2440 - accuracy: 0.8500
# Epoch 160/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2430 - accuracy: 0.8500
# Epoch 161/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2419 - accuracy: 0.8500
# Epoch 162/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2405 - accuracy: 0.9000
# Epoch 163/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2394 - accuracy: 0.9000
# Epoch 164/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2380 - accuracy: 0.9000
# Epoch 165/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2369 - accuracy: 0.9000
# Epoch 166/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2358 - accuracy: 0.9000
# Epoch 167/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2344 - accuracy: 0.9000
# Epoch 168/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2329 - accuracy: 0.9000
# Epoch 169/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2315 - accuracy: 0.9000
# Epoch 170/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2305 - accuracy: 0.9500
# Epoch 171/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2291 - accuracy: 0.9500
# Epoch 172/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2278 - accuracy: 0.9500
# Epoch 173/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2265 - accuracy: 0.9500
# Epoch 174/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2253 - accuracy: 0.9500
# Epoch 175/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2240 - accuracy: 0.9500
# Epoch 176/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2229 - accuracy: 0.9500
# Epoch 177/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2215 - accuracy: 0.9500
# Epoch 178/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2202 - accuracy: 0.9500
# Epoch 179/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2189 - accuracy: 0.9500
# Epoch 180/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2176 - accuracy: 0.9500
# Epoch 181/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2158 - accuracy: 0.9500
# Epoch 182/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2144 - accuracy: 0.9500
# Epoch 183/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2131 - accuracy: 0.9500
# Epoch 184/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2134 - accuracy: 0.9500
# Epoch 185/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2121 - accuracy: 0.9500
# Epoch 186/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2107 - accuracy: 0.9500
# Epoch 187/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2097 - accuracy: 0.9500
# Epoch 188/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2091 - accuracy: 0.9500
# Epoch 189/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2083 - accuracy: 0.9500
# Epoch 190/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2071 - accuracy: 0.9500
# Epoch 191/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2063 - accuracy: 0.9500
# Epoch 192/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2051 - accuracy: 0.9500
# Epoch 193/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2042 - accuracy: 0.9500
# Epoch 194/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2029 - accuracy: 0.9500
# Epoch 195/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2027 - accuracy: 0.9500
# Epoch 196/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2020 - accuracy: 0.9500
# Epoch 197/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2010 - accuracy: 0.9500
# Epoch 198/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2000 - accuracy: 0.9500
# Epoch 199/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1990 - accuracy: 0.9500
# Epoch 200/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1991 - accuracy: 0.9500

# %% [markdown]
# ###Test CNN
# Check for generalization to:
# - untrained retinal positions
# - and  at 2 delta values on either side of original brightness levels

# %%
print('locations trained')
plt.plot(X_locs_trained)
plt.show()

for BrightDelta in range(-45,46,15):
  temp=np.add(Brightnesses,[BrightDelta,-BrightDelta])
  BrightnessesChanged=temp.tolist()

  X_test=generate_bright_test_set(BackGround,BrightnessesChanged,skip,left,hole,right)
  y_test=generate_bright_labels(BrightnessesChanged,X_test)
  #print('test set')
  #for i in range(len(X_test)):
  #  print(X_test[i], 'label',y_test[i])
  #print()


  #Test on all retinal positions including non-trained ones
  # We plot separately the predictions for the two brightness levels at each RetPos
  NumTrials=len(X_test)
  RetinaSize=len(X_test[0])
  resultsCNN=[[0 for row in range(0,2)] for col in range(RetinaSize)]
  for trial in range(NumTrials):
    pred=model.predict(np.array([X_test[trial]]), verbose=0)
    estimate=pred[0][0]
    bright=BrightnessesChanged[y_test[trial]]
    which=BrightnessesChanged.index(bright)
    RetPos=X_test[trial].index(bright)
    #print(which,RetPos,estimate)
    resultsCNN[RetPos][which]=estimate
  #print(resultsNN)
  print('trained Brightnesses:',Brightnesses, 'tested with',BrightnessesChanged,'Delta:', BrightDelta)

  import matplotlib.pyplot as plt
  #plt.suptitle('BrightDelta',BrightDelta)
  plt.plot(resultsCNN)
  plt.show()
# Out:
# locations trained
# trained Brightnesses: [63, 187] tested with [18, 232] Delta: -45
# trained Brightnesses: [63, 187] tested with [33, 217] Delta: -30
# trained Brightnesses: [63, 187] tested with [48, 202] Delta: -15
# trained Brightnesses: [63, 187] tested with [63, 187] Delta: 0
# trained Brightnesses: [63, 187] tested with [78, 172] Delta: 15
# trained Brightnesses: [63, 187] tested with [93, 157] Delta: 30
# trained Brightnesses: [63, 187] tested with [108, 142] Delta: 45

# %% [markdown]
# Comment on results for CNN with kernel and maxpooling = 4:
# Unlike for normal NN, there is an asymmetry between the dim and bright decisiions. For the dim decisions, confidence is very accurate for pixels dimmer than the training, and less accurate for pixels brighter than the training. For the bright pixels, confidence is much more variable, and increases slightly when the pixels get brighter.
#
# Compared to normal NN, for the dim pixels, the CNN smooths well over skipped (non-trained pixels) but not very much into the "hole". For the bright pixels the smoothing is not so good.
